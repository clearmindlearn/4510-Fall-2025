# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the necessary libraries
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
# Load nbaallelo_log.csv into a dataframe
NBA = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/4510/2025-Fall-Lecture/CH7-Regression/data/nbaallelo_log.csv")
NBA
# Out:
#         pts      elo_i  win_equiv game_result
# 0        66  1300.0000  40.294830           L
# 1        68  1300.0000  41.705170           W
# 2        63  1300.0000  42.012257           W
# 3        47  1306.7233  40.692783           L
# 4        33  1300.0000  38.864048           L
# ...     ...        ...        ...         ...
# 126309   82  1723.4149  60.309792           L
# 126310  104  1809.9791  68.013329           W
# 126311   91  1704.3949  60.010067           L
# 126312   97  1700.7391  59.290245           L
# 126313  105  1813.6349  68.519516           W
#
# [126314 rows x 4 columns]

# %%
# Hot encode the game_result variable as a numeric variable with 0 for L and 1 for W
NBA.loc[NBA['game_result']=='L','game_result']=0
NBA.loc[NBA['game_result']=='W','game_result']=1

# %%
# Store relevant columns as variables
X = NBA[['elo_i']].values.reshape(-1, 1)
y = NBA[['game_result']].values.reshape(-1, 1).astype(int)

# %%
from sklearn.model_selection import train_test_split

#Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=123
)

# %%
# Build the logistic model
logisticRegr = LogisticRegression()
model = logisticRegr.fit(X,np.ravel(y.astype(int)))

# %%
# Predict the probability that an elo_i score of 1310 is a win / loss
#outcomeProb = logisticRegr.predict_proba([[1310]])

# %%
# Predict whether an elo_i score of 1310 is a win (1) or loss (0)
#outcomePred = logisticRegr.predict([[1310]])

# %%
#print("A team with the given elo_i score has predicted probability: \n", end="")
#print('%.3f' % outcomeProb[0][0] + " losing\n", end="")
#print('%.3f' % outcomeProb[0][1] + " winning")
#print("and the overall prediction is",
 #    outcomePred[0])

# %%
from sklearn import metrics

p_hat = model.predict_proba(X_test)
metrics.log_loss(y_test , p_hat)
# Out:
# 0.6658496570499456
