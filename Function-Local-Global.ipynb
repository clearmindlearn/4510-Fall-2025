# %%
x = 1
y = 2

def sum_two (a, b):
  sum = a + b
  return sum

#I would like to invoke (or call) the function sum_two
total = sum_two(x,y)
print (total)
# Out:
# 3

# %%
x = 1

def hi(x):
  x = 100
  x = 200
  print(x)

hi(x)
print(x)
# Out:
# 200
# 1
