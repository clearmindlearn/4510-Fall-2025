# %%
prices = {'apple':1.99, 'orange':1.49  }
#each element --> key:vlaue pair

# %%
prices['banan'] = 1.69
prices
# Out:
# {'apple': 1.99, 'orange': 1.49, 'banan': 1.69}

# %%
del prices['apple']
#prices
print(prices)
# Out:
# {'orange': 1.49, 'banan': 1.69}

# %%
prices['banan'] = 2.01
prices
# Out:
# {'orange': 1.49, 'banan': 2.01}
