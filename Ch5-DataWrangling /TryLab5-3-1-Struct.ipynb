# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import packages
import pandas as pd
from sklearn import preprocessing

# %%
# Import data into 'original'
original = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ZybookDataScience/Ch5-Data-Wrangling/Data/featurescaling.csv')

original
# Out:
#     Price  Age
# 0   90300   14
# 1  150500   27
# 2  269500   22
# 3   98000   15
# 4  244650   28

# %%
# Standardize dataframe and return as an array
standardizedArray = preprocessing.scale(original)

standardizedArray

# %%
# Convert standardized array to dataframe 'standardized'
standardized = pd.DataFrame(standardizedArray, columns=["Price", "Age"])

standardized
# Out:
#       Price       Age
# 0 -1.084852 -1.231895
# 1 -0.271449  0.992360
# 2  1.336439  0.136877
# 3 -0.980812 -1.060798
# 4  1.000674  1.163456

# %%
# Verify that standardized contains the expected values

# %%
# Normalize dataframe and return as an array
normalizedArray = preprocessing.MinMaxScaler().fit_transform(original)

normalizedArray
# Out:
# array([[0.        , 0.        ],
#        [0.3359375 , 0.92857143],
#        [1.        , 0.57142857],
#        [0.04296875, 0.07142857],
#        [0.86132812, 1.        ]])

# %%
# Convert normalized array to dataframe 'normalized'
normalized = pd.DataFrame(normalizedArray, columns=["Price", "Age"])

normalized
# Out:
#       Price       Age
# 0  0.000000  0.000000
# 1  0.335938  0.928571
# 2  1.000000  0.571429
# 3  0.042969  0.071429
# 4  0.861328  1.000000

# %%
# Verify that normalized contains the expected values
