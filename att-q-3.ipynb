# %%
scores = [1,2,"apple", 4,5]
scores.append("hi")
scores.pop(2)
scores
# Out:
# [1, 2, 4, 5, 'hi']

# %%
def try_to_modify(x):
  x = 100   # Is x local or global?


x = 200     # Is x local or global?
try_to_modify(x)
print (x)
# Out:
# 200

# %%
def modify(numList):
  numList[1] = 99

list = [20, 30, 40]
modify(list)
print(list)
# Out:
# [20, 99, 40]
